# %%
import pandas as pd
df=pd.read_csv('car_price.csv')
df
# Out:
#       Unnamed: 0                                car_name car_prices_in_rupee  \
# 0              0  Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh
# 1              1            Renault Duster RXZ Turbo CVT          12.83 Lakh
# 2              2                      Toyota Camry 2.5 G          16.40 Lakh
# 3              3                       Honda Jazz VX CVT           7.77 Lakh
# 4              4        Volkswagen Polo 1.2 MPI Highline           5.15 Lakh
# ...          ...                                     ...                 ...
# 5507        5507                 BMW X1 sDrive 20d xLine          28.90 Lakh
# 5508        5508                   BMW M Series M4 Coupe          64.90 Lakh
# 5509        5509              Jaguar XF 2.2 Litre Luxury          13.75 Lakh
# 5510        5510                      BMW 7 Series 730Ld          29.90 Lakh
# 5511        5511               BMW 5 Series 520d M Sport          31.90 Lakh
#
# ...

# %%
df.values
# Out:
# array([[0, 'Jeep Compass 2.0 Longitude Option BSIV', '10.03 Lakh', ...,
#         2017.0, '1956 cc', '5 Seats'],
#        [1, 'Renault Duster RXZ Turbo CVT', '12.83 Lakh', ..., 2021.0,
#         '1330 cc', '5 Seats'],
#        [2, 'Toyota Camry 2.5 G', '16.40 Lakh', ..., 2016.0, '2494 cc',
#         '5 Seats'],
#        ...,
#        [5509, 'Jaguar XF 2.2 Litre Luxury', '13.75 Lakh', ..., 2013.0,
#         '2755 cc', '5 Seats'],
#        [5510, 'BMW 7 Series 730Ld', '29.90 Lakh', ..., 2015.0, '2967 cc',
#         '6 Seats'],
#        [5511, 'BMW 5 Series 520d M Sport', '31.90 Lakh', ..., 2017.0,
#         '1991 cc', '5 Seats']], dtype=object)

# %%
df = df[(df["engine"] >= 624) & (df["engine"] <= 6000)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 df = df[(df["engine"] >= 624) & (df["engine"] <= 6000)]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arraylike.py:62, in OpsMixin.__ge__(self, other)
#      60 @unpack_zerodim_and_defer("__ge__")
#      61 def __ge__(self, other):
# ---> 62     return self._cmp_method(other, operator.ge)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:6243, in Series._cmp_method(self, other, op)
# ...
